# %%
import random # библиотека для генерации случайных чисел

# генерируем случайное целое число (random integer) от 0 до 10
# функция randint принимает два аргумента: диапазон генерации
magic_number = random.randint(0, 10)

# запросите у пользователя ввод числа
user_input = input("Угадайте число от 0 до 10: ")

# Выводим введенное пользователем значение
print("Вы ввели:", user_input)

if user_input == magic_number: # проверка на совпадение значений
  print('Поздравляю, вы угадали!')
else:
  print('А вот и нет! Это число', magic_number)
# Out:
# Угадайте число от 0 до 10: 5
# Вы ввели: 5
# А вот и нет! Это число 8

# %%
# запросите у пользователя его имя
# вспомните, чем input(int()) отличается от input()
user_input = input("Введите ваше имя: ")
# выведите на экран любое приветствие для пользователя
print('Здравствуйте,', user_input,'!')
# Out:
# Введите ваше имя: Машка
# Здравствуйте, Машка !

# %%
# запросите у пользователя температуру в градусах Цельсия:
# это должно быть дробное числом (float)
user_input = float(input("Введите температуру в градусах Цельсия: "))

# конвертируйте температуру из градусов Цельсия в градусы Фаренгейта:
# вспомните или найдите формулу и используйте арифметические операции python для расчетов
result=user_input*1.8+32

# выведите результат на экран:
# используйте любые текстовые формулировки, чтобы показать число,
# которое вы получили от пользователя, и результат расчетов
output = f'Ваше значение в градусах Цельсия: {user_input}\nА это в градусах Фаренгейта: {result}'
print(output)
# Out:
# Введите температуру в градусах Цельсия: 19.7
# Ваше значение в градусах Цельсия: 19.7
# А это в градусах Фаренгейта: 67.46000000000001

# %%
# 4
# результат расчетов в задаче 3 сохранился в переменных
# воспользуемся этим преимуществом!

# округлите оба значения температур в градусах Цельсия и в градусах Фаренгейта
# используем функцию round() для округления до 2 знаков после запятой
rounded_celsius_round = round(user_input, 2)
rounded_fahrenheit_round = round(result, 2)

# используем преобразование к целому числу с помощью int()
rounded_celsius_int = int(user_input)
rounded_fahrenheit_int = int(result)

# теперь выведите на экран оба числа
# сделайте это в одну строчку кода:
# используем символ новой строки \n
print(f'Округленное значение в градусах Цельсия (round): {rounded_celsius_round}, Округленное значение в градусах Фаренгейта (round): {rounded_fahrenheit_round}, Целое значение в градусах Цельсия (int): {rounded_celsius_int}, Целое значение в градусах Фаренгейта (int): {rounded_fahrenheit_int}')
# Out:
# Округленное значение в градусах Цельсия (round): 19.7, Округленное значение в градусах Фаренгейта (round): 67.46, Целое значение в градусах Цельсия (int): 19, Целое значение в градусах Фаренгейта (int): 67

# %%
#5
# преобразуйте округленные значения температур к виду строк, применив str(n),
# где n - то, что вы хотите преобразовать к виду строки
rounded_celsius_round_str = str(rounded_celsius_round)
rounded_fahrenheit_round_str = str(rounded_fahrenheit_round)
rounded_celsius_int_str = str(rounded_celsius_int)
rounded_fahrenheit_int_str = str(rounded_fahrenheit_int)

# выведите на экран результат:
# используйте конкатенацию строк вместо запятой в функции
print('Округленное значение в градусах Цельсия: ' + rounded_celsius_round_str +
      ', Целое значение в градусах Фаренгейта (round): ' + rounded_fahrenheit_round_str +
      ', Округленное значение в градусах Цельсия (int): ' + rounded_celsius_int_str +
      ', Целое значение в градусах Фаренгейта (int): ' + rounded_fahrenheit_int_str)
# Out:
# Округленное значение в градусах Цельсия: 19.7, Целое значение в градусах Фаренгейта (round): 67.46, Округленное значение в градусах Цельсия (int): 19, Целое значение в градусах Фаренгейта (int): 67

# %%
# 6
# запросите у пользователя 2 целых числа
# выполните операции сложения, вычитания, умножения и возведения каждого из чисел во вторую степень
# выведите результат на экран

num1 = int(input("Введите первое целое число: "))
num2 = int(input("Введите второе целое число: "))

# арифметика
sum_result = num1 + num2
diff_result = num1 - num2
prod_result = num1 * num2
pow1_result = num1 ** 2
pow2_result = num2 ** 2

# выводим с подписями
print(f"Сумма чисел: {sum_result}")
print(f"Разность чисел: {diff_result}")
print(f"Произведение чисел: {prod_result}")
print(f"Квадрат первого числа: {pow1_result}")
print(f"Квадрат второго числа: {pow2_result}")
# Out:
# Введите первое целое число: 5
# Введите второе целое число: 7
# Сумма чисел: 12
# Разность чисел: -2
# Произведение чисел: 35
# Квадрат первого числа: 25
# Квадрат второго числа: 49

# %%
#7

# вспомним множественное присваивание в python
# a, b, c = 0, 1, 2
# используйте множественное присваивание,
# чтобы одной строчкой кода запросить у пользователя имя, возраст и профессию
# выведите на экран полученную информацию

name, age, profession = input("Введите ваше имя: "), input("Введите ваш возраст: "), input("Введите вашу профессию: ")

print(f"Имя: {name}")
print(f"Возраст: {age}")
print(f"Профессия: {profession}")
# Out:
# Введите ваше имя: Машка
# Введите ваш возраст: 22
# Введите вашу профессию: студент
# Имя: Машка
# Возраст: 22
# Профессия: студент

# %%
#8
# множественное присваивание иногда очень полезно
# запросите у пользователя две любые переменные
# это может быть строка или число, на ваш выбор

# поменяйте их местами одной строчкой кода:
# запишите в первую переменную информацию из второй,
# а во вторую переменную - информацию из первой, используя множественное присваивание

# выведите на экран промежуточные и итоговые результаты

# Запрашиваем
var1 = input("Введите первую переменную: ")
var2 = input("Введите вторую переменную: ")

# Выводим промежуточный результат)
print(f"Начальные значения: var1 = {var1}, var2 = {var2}")

# Меняем местами (a-ka множественно присваиваем)
var1, var2 = var2, var1

# Выводим итоговый результат
print(f"Итоговые значения: var1 = {var1}, var2 = {var2}")
# Out:
# Введите первую переменную: 5
# Введите вторую переменную: существительное
# Начальные значения: var1 = 5, var2 = существительное
# Итоговые значения: var1 = существительное, var2 = 5

# %%
#9
# чаще мы используем множественное присваивание в фунциональном программировании
# например, эта функция считает сумму и произведение двух чисел
# функция принимает на вход (почти как input!) 2 числа
# эти числа запишутся в переменные a и b

def sum_and_product(a, b):
    # напишите здесь код для расчета суммы чисел a и b
    total_sum = a + b
    # а сюда допишите код для подсчета их произведения
    product =  a * b
    # функция возвращает результат подсчета - два новых числа
    return total_sum, product

# настало время множественного присваивания
# мы вызывает функцию sum_and_product и передаем ей в качестве аргументов два числа - 5 и 3
# мы помним, что функция возвращает 2 новых числа,
# поэтому результат работы одной функции мы записываем в две переменные: result_sum и result_product

result_sum, result_product = sum_and_product(5, 3)

# выведите на экран result_sum и result_product
print("Сумма:", result_sum)
print("Произведение:", result_product)
# Out:
# Сумма: 8
# Произведение: 15

# %%
# 10
# запросите у пользователя 2 числа, используйте str(input())
# сложите два числа, не меняя тип данных, и выведите на экран результат
# преобразуйте числа к виду нужного типа и снова сложите их, выведите результат

num1, num2 = str(input("Введите первое число: ")), str(input("Введите второе число: "))

# это задание нам уже знакомо:
# попробуйте решить его питонично, используя как можно меньше строк кода
# какие операции можно объединить?
# в каких случаях нам не нужно создавать дополнительные переменные?
# Запрос двух чисел у пользователя

# вывод: сложение строк
print("Сложение строк:", num1 + num2)

# вывод: проеобразование и сложение
print("Сложение чисел:", int(num1) + int(num2))
# Out:
# Введите первое число: 5
# Введите второе число: 9
# Сложение строк: 59
# Сложение чисел: 14
